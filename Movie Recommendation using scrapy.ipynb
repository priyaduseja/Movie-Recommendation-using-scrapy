# %% [markdown]
# #### Building Movie Recommendation using scrapy

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

class MovieRecommendation(scrapy.Spider):
    name = 'IMDB_Movies'
    start_urls = ['https://www.imdb.com/chart/top/']
    custom_settings = {'DEFAULT_REQUEST_HEADERS': {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',}}
    
    def parse(self, response):
        for movie in response.css('ul.ipc-metadata-list li'):
            movieName = movie.css('div.ipc-title a h3::text').get()
            movieUrl = movie.css('div.ipc-title a::attr(href)').get()
            dic = {'movieName': movieName}
            yield response.follow(movieUrl, callback = self.movieParseInfo, meta=dic,dont_filter=True)
            
    def movieParseInfo(self, response):
        movieName = response.meta['movieName']
        dire = response.css('ul.ipc-metadata-list.ipc-metadata-list--dividers-all.sc-bfec09a1-8.bHYmJY.ipc-metadata-list--base:first-of-type li:first-of-type span[aria-label="See full cast and crew"] + div a.ipc-metadata-list-item__list-content-item--link')
        directorurl = dire[0].css('::attr(href)').get()
        directorname = dire[0].css('::text').get()
        dir_dic = {'movieName': movieName,'directorName': directorname}
        yield response.follow(directorurl, callback = self.directorparseinfo, meta=dir_dic,dont_filter=True)
        
    def directorparseinfo(self, response):
        movieName = response.meta['movieName']
        directorName = response.meta['directorName']
        top4movies = response.css('div[data-testid="nm_flmg_kwn_for"] div.ipc-primary-image-list-card__content a::text').getall()
        top4movies = ','.join(top4movies)
        yield {'MovieName': movieName, 'DirectorName' : directorName, 'Top Four Movies': top4movies }
            
process = CrawlerProcess(settings = {'FEEDS': {'MovieRecommendation_using_scrapy.csv': {'format': 'csv'}}})
process.crawl(MovieRecommendation)
process.start()
# Out:
# 2024-04-06 00:17:15 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2024-04-06 00:17:15 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1q  5 Jul 2022), cryptography 37.0.1, Platform Windows-10-10.0.19045-SP0
# 2024-04-06 00:17:15 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2024-04-06 00:17:15 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-04-06 00:17:15 [scrapy.extensions.telnet] INFO: Telnet Password: 1fe803a084af3543
# 2024-04-06 00:17:15 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-04-06 00:17:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-04-06 00:17:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-04-06 00:17:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-04-06 00:17:15 [scrapy.core.engine] INFO: Spider opened
# 2024-04-06 00:17:16 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-04-06 00:17:16 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-04-06 00:17:19 [filelock] DEBUG: Attempting to acquire lock 2656977126880 on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2024-04-06 00:17:19 [filelock] DEBUG: Lock 2656977126880 acquired on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2024-04-06 00:17:19 [filelock] DEBUG: Attempting to acquire lock 2656977320160 on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2024-04-06 00:17:19 [filelock] DEBUG: Lock 2656977320160 acquired on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2024-04-06 00:17:19 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): publicsuffix.org:443
# 2024-04-06 00:17:20 [filelock] DEBUG: Attempting to release lock 2656977320160 on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2024-04-06 00:17:20 [filelock] DEBUG: Lock 2656977320160 released on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2024-04-06 00:17:20 [tldextract] ERROR: Exception reading Public Suffix List url https://publicsuffix.org/list/public_suffix_list.dat
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 1660, in _inlineCallbacks
#     result = current_context.run(gen.send, result)
# StopIteration: <200 https://www.imdb.com/chart/top/>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 190, in run_and_cache
#     result = self.get(namespace=namespace, key=key_args)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 93, in get
#     raise KeyError("namespace: " + namespace + " key: " + repr(key))
# KeyError: "namespace: publicsuffix.org-tlds key: {'urls': ('https://publicsuffix.org/list/public_suffix_list.dat', 'https://raw.githubusercontent.com/publicsuffix/list/master/public_suffix_list.dat'), 'fallback_to_snapshot': True}"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 190, in run_and_cache
#     result = self.get(namespace=namespace, key=key_args)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 93, in get
#     raise KeyError("namespace: " + namespace + " key: " + repr(key))
# KeyError: "namespace: urls key: {'url': 'https://publicsuffix.org/list/public_suffix_list.dat'}"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\pduseja\Anaconda3\lib\ssl.py", line 501, in wrap_socket
#     return self.sslsocket_class._create(
#   File "C:\Users\pduseja\Anaconda3\lib\ssl.py", line 1041, in _create
#     self.do_handshake()
#   File "C:\Users\pduseja\Anaconda3\lib\ssl.py", line 1310, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='publicsuffix.org', port=443): Max retries exceeded with url: /list/public_suffix_list.dat (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\suffix_list.py", line 30, in find_first_response
#     return cache.cached_fetch_url(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 199, in cached_fetch_url
#     return self.run_and_cache(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 192, in run_and_cache
#     result = func(**kwargs)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 209, in _fetch_url
#     response = session.get(url, timeout=timeout)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\sessions.py", line 600, in get
#     return self.request("GET", url, **kwargs)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\adapters.py", line 563, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='publicsuffix.org', port=443): Max retries exceeded with url: /list/public_suffix_list.dat (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)')))
# 2024-04-06 00:17:20 [filelock] DEBUG: Attempting to acquire lock 2656977320256 on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\2857a861fad3e342b67f126bcac61993.tldextract.json.lock
# 2024-04-06 00:17:20 [filelock] DEBUG: Lock 2656977320256 acquired on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\2857a861fad3e342b67f126bcac61993.tldextract.json.lock
# 2024-04-06 00:17:20 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): raw.githubusercontent.com:443
# 2024-04-06 00:17:20 [filelock] DEBUG: Attempting to release lock 2656977320256 on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\2857a861fad3e342b67f126bcac61993.tldextract.json.lock
# 2024-04-06 00:17:20 [filelock] DEBUG: Lock 2656977320256 released on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\2857a861fad3e342b67f126bcac61993.tldextract.json.lock
# 2024-04-06 00:17:20 [tldextract] ERROR: Exception reading Public Suffix List url https://raw.githubusercontent.com/publicsuffix/list/master/public_suffix_list.dat
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 1660, in _inlineCallbacks
#     result = current_context.run(gen.send, result)
# StopIteration: <200 https://www.imdb.com/chart/top/>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 190, in run_and_cache
#     result = self.get(namespace=namespace, key=key_args)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 93, in get
#     raise KeyError("namespace: " + namespace + " key: " + repr(key))
# KeyError: "namespace: publicsuffix.org-tlds key: {'urls': ('https://publicsuffix.org/list/public_suffix_list.dat', 'https://raw.githubusercontent.com/publicsuffix/list/master/public_suffix_list.dat'), 'fallback_to_snapshot': True}"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 190, in run_and_cache
#     result = self.get(namespace=namespace, key=key_args)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 93, in get
#     raise KeyError("namespace: " + namespace + " key: " + repr(key))
# KeyError: "namespace: urls key: {'url': 'https://raw.githubusercontent.com/publicsuffix/list/master/public_suffix_list.dat'}"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\pduseja\Anaconda3\lib\ssl.py", line 501, in wrap_socket
#     return self.sslsocket_class._create(
#   File "C:\Users\pduseja\Anaconda3\lib\ssl.py", line 1041, in _create
#     self.do_handshake()
#   File "C:\Users\pduseja\Anaconda3\lib\ssl.py", line 1310, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='raw.githubusercontent.com', port=443): Max retries exceeded with url: /publicsuffix/list/master/public_suffix_list.dat (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\suffix_list.py", line 30, in find_first_response
#     return cache.cached_fetch_url(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 199, in cached_fetch_url
#     return self.run_and_cache(
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 192, in run_and_cache
#     result = func(**kwargs)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\cache.py", line 209, in _fetch_url
#     response = session.get(url, timeout=timeout)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\sessions.py", line 600, in get
#     return self.request("GET", url, **kwargs)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\pduseja\Anaconda3\lib\site-packages\requests\adapters.py", line 563, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='raw.githubusercontent.com', port=443): Max retries exceeded with url: /publicsuffix/list/master/public_suffix_list.dat (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)')))
# 2024-04-06 00:17:20 [filelock] DEBUG: Attempting to release lock 2656977126880 on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2024-04-06 00:17:20 [filelock] DEBUG: Lock 2656977126880 released on C:\Users\pduseja\Anaconda3\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2024-04-06 00:17:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/chart/top/> (referer: None)
# 2024-04-06 00:17:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt15239678/?ref_=chttp_t_15> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0109830/?ref_=chttp_t_11> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt1375666/?ref_=chttp_t_14> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0137523/?ref_=chttp_t_13> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0167261/?ref_=chttp_t_12> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0120737/?ref_=chttp_t_9> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0110912/?ref_=chttp_t_8> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0060196/?ref_=chttp_t_10> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0108052/?ref_=chttp_t_6> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0071562/?ref_=chttp_t_4> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0167260/?ref_=chttp_t_7> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0050083/?ref_=chttp_t_5> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0064116/?ref_=chttp_t_52> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0468569/?ref_=chttp_t_3> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0099348/?ref_=chttp_t_249> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0068646/?ref_=chttp_t_2> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001104/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1)
# 2024-04-06 00:17:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0898288/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt15239678/?ref_=chttp_t_15)
# 2024-04-06 00:17:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001104/?ref_=tt_cl_dr_1>
# {'MovieName': '1. The Shawshank Redemption', 'DirectorName': 'Frank Darabont', 'Top Four Movies': 'The Shawshank Redemption,The Green Mile,The Mist,The Walking Dead'}
# 2024-04-06 00:17:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0898288/?ref_=tt_cl_dr_1>
# {'MovieName': '15. Dune: Part Two', 'DirectorName': 'Denis Villeneuve', 'Top Four Movies': 'Dune,Blade Runner 2049,Arrival,Incendies'}
# 2024-04-06 00:17:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0103639/?ref_=chttp_t_248> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0087884/?ref_=chttp_t_250> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001392/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0120737/?ref_=chttp_t_9)
# 2024-04-06 00:17:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001466/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0060196/?ref_=chttp_t_10)
# 2024-04-06 00:17:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001392/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0167261/?ref_=chttp_t_12)
# 2024-04-06 00:17:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001392/?ref_=tt_cl_dr_1>
# {'MovieName': '9. The Lord of the Rings: The Fellowship of the Ring', 'DirectorName': 'Peter Jackson', 'Top Four Movies': 'The Lord of the Rings: The Fellowship of the Ring,Bad Taste,The Lord of the Rings: The Two Towers,The Lord of the Rings: The Return of the King'}
# 2024-04-06 00:17:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001466/?ref_=tt_cl_dr_1>
# {'MovieName': '10. Il Buono, Il Brutto, Il Cattivo', 'DirectorName': 'Sergio Leone', 'Top Four Movies': "Once Upon a Time in America,Fistful of Dynamite,A Fistful of Dollars,C'era Una Volta Il West"}
# 2024-04-06 00:17:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001392/?ref_=tt_cl_dr_1>
# {'MovieName': '12. The Lord of the Rings: The Two Towers', 'DirectorName': 'Peter Jackson', 'Top Four Movies': 'The Lord of the Rings: The Fellowship of the Ring,Bad Taste,The Lord of the Rings: The Two Towers,The Lord of the Rings: The Return of the King'}
# 2024-04-06 00:17:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000233/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0110912/?ref_=chttp_t_8)
# 2024-04-06 00:17:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000233/?ref_=tt_cl_dr_1>
# {'MovieName': '8. Pulp Fiction', 'DirectorName': 'Quentin Tarantino', 'Top Four Movies': 'Reservoir Dogs,Pulp Fiction,Once Upon a Time... In Hollywood,From Dusk Till Dawn'}
# 2024-04-06 00:17:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001466/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0064116/?ref_=chttp_t_52)
# 2024-04-06 00:17:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001466/?ref_=tt_cl_dr_1>
# {'MovieName': "52. C'era Una Volta Il West", 'DirectorName': 'Sergio Leone', 'Top Four Movies': "Once Upon a Time in America,Fistful of Dynamite,A Fistful of Dollars,C'era Una Volta Il West"}
# 2024-04-06 00:17:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0634240/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt1375666/?ref_=chttp_t_14)
# 2024-04-06 00:17:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0634240/?ref_=tt_cl_dr_1>
# {'MovieName': '14. Inception', 'DirectorName': 'Christopher Nolan', 'Top Four Movies': 'Tenet,Interstellar,Inception,The Prestige'}
# 2024-04-06 00:17:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000338/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0071562/?ref_=chttp_t_4)
# 2024-04-06 00:17:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000338/?ref_=tt_cl_dr_1>
# {'MovieName': '4. The Godfather: Part II', 'DirectorName': 'Francis Ford Coppola', 'Top Four Movies': 'Apocalypse Now,The Conversation,The Godfather,The Godfather: Part II'}
# 2024-04-06 00:17:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001486/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0050083/?ref_=chttp_t_5)
# 2024-04-06 00:17:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001486/?ref_=tt_cl_dr_1>
# {'MovieName': '5. 12 Angry Men', 'DirectorName': 'Sidney Lumet', 'Top Four Movies': "12 Angry Men,Before the Devil Knows You're Dead,Serpico,Dog Day Afternoon"}
# 2024-04-06 00:17:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001392/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0167260/?ref_=chttp_t_7)
# 2024-04-06 00:17:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001392/?ref_=tt_cl_dr_1>
# {'MovieName': '7. The Lord of the Rings: The Return of the King', 'DirectorName': 'Peter Jackson', 'Top Four Movies': 'The Lord of the Rings: The Fellowship of the Ring,Bad Taste,The Lord of the Rings: The Two Towers,The Lord of the Rings: The Return of the King'}
# 2024-04-06 00:17:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0634240/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0468569/?ref_=chttp_t_3)
# 2024-04-06 00:17:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0634240/?ref_=tt_cl_dr_1>
# {'MovieName': '3. The Dark Knight', 'DirectorName': 'Christopher Nolan', 'Top Four Movies': 'Tenet,Interstellar,Inception,The Prestige'}
# 2024-04-06 00:17:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000126/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0099348/?ref_=chttp_t_249)
# 2024-04-06 00:17:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000126/?ref_=tt_cl_dr_1>
# {'MovieName': '249. Dances with Wolves', 'DirectorName': 'Kevin Costner', 'Top Four Movies': 'The Postman,Dances with Wolves,Robin Hood: Prince of Thieves,The Bodyguard'}
# 2024-04-06 00:17:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000229/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0108052/?ref_=chttp_t_6)
# 2024-04-06 00:17:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000229/?ref_=tt_cl_dr_1>
# {'MovieName': "6. Schindler's List", 'DirectorName': 'Steven Spielberg', 'Top Four Movies': "Schindler's List,E.T. The Extra-Terrestrial,Saving Private Ryan,Raiders of the Lost Ark"}
# 2024-04-06 00:17:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0166256/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0103639/?ref_=chttp_t_248)
# 2024-04-06 00:17:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0166256/?ref_=tt_cl_dr_1>
# {'MovieName': '248. Aladdin', 'DirectorName': 'Ron Clements', 'Top Four Movies': 'Hercules,Aladdin,The Princess and the Frog,Moana'}
# 2024-04-06 00:17:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000338/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0068646/?ref_=chttp_t_2)
# 2024-04-06 00:17:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000338/?ref_=tt_cl_dr_1>
# {'MovieName': '2. The Godfather', 'DirectorName': 'Francis Ford Coppola', 'Top Four Movies': 'Apocalypse Now,The Conversation,The Godfather,The Godfather: Part II'}
# 2024-04-06 00:17:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0025316/?ref_=chttp_t_247> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt1454029/?ref_=chttp_t_246> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000709/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0109830/?ref_=chttp_t_11)
# 2024-04-06 00:17:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000709/?ref_=tt_cl_dr_1>
# {'MovieName': '11. Forrest Gump', 'DirectorName': 'Robert Zemeckis', 'Top Four Movies': 'Back to the Future,Forrest Gump,Contact,Flight'}
# 2024-04-06 00:17:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0129167/?ref_=chttp_t_245> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0032976/?ref_=chttp_t_243> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0061512/?ref_=chttp_t_244> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0245712/?ref_=chttp_t_242> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0107048/?ref_=chttp_t_241> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0058946/?ref_=chttp_t_240> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0032551/?ref_=chttp_t_239> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0035446/?ref_=chttp_t_238> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0059742/?ref_=chttp_t_237> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0476735/?ref_=chttp_t_236> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0758758/?ref_=chttp_t_235> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt4016934/?ref_=chttp_t_234> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0853238/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt1454029/?ref_=chttp_t_246)
# 2024-04-06 00:17:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0853238/?ref_=tt_cl_dr_1>
# {'MovieName': '246. The Help', 'DirectorName': 'Tate Taylor', 'Top Four Movies': 'Get on Up,The Help,The Girl on the Train,Ma'}
# 2024-04-06 00:17:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0083348/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0129167/?ref_=chttp_t_245)
# 2024-04-06 00:17:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000033/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0032976/?ref_=chttp_t_243)
# 2024-04-06 00:17:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0083348/?ref_=tt_cl_dr_1>
# {'MovieName': '245. The Iron Giant', 'DirectorName': 'Brad Bird', 'Top Four Movies': 'The Incredibles,Ratatouille,Incredibles 2,The Iron Giant'}
# 2024-04-06 00:17:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000033/?ref_=tt_cl_dr_1>
# {'MovieName': '243. Rebecca', 'DirectorName': 'Alfred Hitchcock', 'Top Four Movies': 'Psycho,North by Northwest,Vertigo,The Birds'}
# 2024-04-06 00:17:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001008/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0025316/?ref_=chttp_t_247)
# 2024-04-06 00:17:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001008/?ref_=tt_cl_dr_1>
# {'MovieName': '247. It Happened One Night', 'DirectorName': 'Frank Capra', 'Top Four Movies': "It's a Wonderful Life,It Happened One Night,You Can't Take It with You,Mr. Smith Goes to Washington"}
# 2024-04-06 00:17:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0327944/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0245712/?ref_=chttp_t_242)
# 2024-04-06 00:17:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0327944/?ref_=tt_cl_dr_1>
# {'MovieName': '242. Amores perros', 'DirectorName': 'Alejandro G. Iñárritu', 'Top Four Movies': 'Biutiful,The Revenant,Birdman or (The Unexpected Virtue of Ignorance),Babel'}
# 2024-04-06 00:17:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0690597/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0058946/?ref_=chttp_t_240)
# 2024-04-06 00:17:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0690597/?ref_=tt_cl_dr_1>
# {'MovieName': '240. La battaglia di Algeri', 'DirectorName': 'Gillo Pontecorvo', 'Top Four Movies': 'La battaglia di Algeri,Ogro,Kapò,Burn!'}
# 2024-04-06 00:17:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0742341/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0061512/?ref_=chttp_t_244)
# 2024-04-06 00:17:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0742341/?ref_=tt_cl_dr_1>
# {'MovieName': '244. Cool Hand Luke', 'DirectorName': 'Stuart Rosenberg', 'Top Four Movies': 'Cool Hand Luke,Question 7,The Defenders,The Amityville Horror'}
# 2024-04-06 00:17:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000601/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0107048/?ref_=chttp_t_241)
# 2024-04-06 00:17:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000601/?ref_=tt_cl_dr_1>
# {'MovieName': '241. Groundhog Day', 'DirectorName': 'Harold Ramis', 'Top Four Movies': 'Ghostbusters,Groundhog Day,Stripes,Knocked Up'}
# 2024-04-06 00:17:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0523932/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0035446/?ref_=chttp_t_238)
# 2024-04-06 00:17:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0523932/?ref_=tt_cl_dr_1>
# {'MovieName': '238. To Be or Not to Be', 'DirectorName': 'Ernst Lubitsch', 'Top Four Movies': 'To Be or Not to Be,The Shop Around the Corner,Heaven Can Wait,The Patriot'}
# 2024-04-06 00:17:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0936404/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0059742/?ref_=chttp_t_237)
# 2024-04-06 00:17:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0936404/?ref_=tt_cl_dr_1>
# {'MovieName': '237. The Sound of Music', 'DirectorName': 'Robert Wise', 'Top Four Movies': 'West Side Story,The Sound of Music,The Andromeda Strain,The Haunting'}
# 2024-04-06 00:17:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000406/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0032551/?ref_=chttp_t_239)
# 2024-04-06 00:17:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000406/?ref_=tt_cl_dr_1>
# {'MovieName': '239. The Grapes of Wrath', 'DirectorName': 'John Ford', 'Top Four Movies': "The Man Who Didn't Talk Too Much,The Grapes of Wrath,How Green Was My Valley,Stagecoach"}
# 2024-04-06 00:17:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm1463981/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0476735/?ref_=chttp_t_236)
# 2024-04-06 00:17:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm1463981/?ref_=tt_cl_dr_1>
# {'MovieName': '236. My Father and My Son', 'DirectorName': 'Çagan Irmak', 'Top Four Movies': 'My Father and My Son,Alone,Ulak,Dedemin Insanlari'}
# 2024-04-06 00:17:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0032138/?ref_=chttp_t_231> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000576/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0758758/?ref_=chttp_t_235)
# 2024-04-06 00:17:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000576/?ref_=tt_cl_dr_1>
# {'MovieName': '235. Into the Wild', 'DirectorName': 'Sean Penn', 'Top Four Movies': 'Mystic River,21 Grams,Milk,Dead Man Walking'}
# 2024-04-06 00:17:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0661791/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt4016934/?ref_=chttp_t_234)
# 2024-04-06 00:17:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0661791/?ref_=tt_cl_dr_1>
# {'MovieName': '234. Ah-ga-ssi', 'DirectorName': 'Park Chan-wook', 'Top Four Movies': 'Ah-ga-ssi,Oldeuboi,Decision to Leave,Bakjwi'}
# 2024-04-06 00:17:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0092005/?ref_=chttp_t_230> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt15097216/?ref_=chttp_t_228> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt1979320/?ref_=chttp_t_227> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0070047/?ref_=chttp_t_225> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0325980/?ref_=chttp_t_226> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0036868/?ref_=chttp_t_224> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0113247/?ref_=chttp_t_223> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0381681/?ref_=chttp_t_222> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0019254/?ref_=chttp_t_221> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0088247/?ref_=chttp_t_220> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0281808/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0032138/?ref_=chttp_t_231)
# 2024-04-06 00:17:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0091763/?ref_=chttp_t_219> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0281808/?ref_=tt_cl_dr_1>
# {'MovieName': '231. The Wizard of Oz', 'DirectorName': 'Victor Fleming', 'Top Four Movies': 'Gone with the Wind,The Wizard of Oz,Captains Courageous,A Guy Named Joe'}
# 2024-04-06 00:17:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001661/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0092005/?ref_=chttp_t_230)
# 2024-04-06 00:17:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001661/?ref_=tt_cl_dr_1>
# {'MovieName': '230. Stand by Me', 'DirectorName': 'Rob Reiner', 'Top Four Movies': 'All in the Family,Spinal Tap,The Wolf of Wall Street,The Story of Us'}
# 2024-04-06 00:17:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm4377096/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt15097216/?ref_=chttp_t_228)
# 2024-04-06 00:17:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm4377096/?ref_=tt_cl_dr_1>
# {'MovieName': '228. Jai Bhim', 'DirectorName': 'T.J. Gnanavel', 'Top Four Movies': 'Jai Bhim,Kootathil Oruthan,Vettaiyan,Payanam'}
# 2024-04-06 00:17:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000165/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt1979320/?ref_=chttp_t_227)
# 2024-04-06 00:17:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000165/?ref_=tt_cl_dr_1>
# {'MovieName': '227. Rush', 'DirectorName': 'Ron Howard', 'Top Four Movies': 'Arrested Development,A Beautiful Mind,The Shootist,Apollo 13'}
# 2024-04-06 00:17:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0395169/?ref_=chttp_t_218> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:17:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0893659/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0325980/?ref_=chttp_t_226)
# 2024-04-06 00:17:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0893659/?ref_=tt_cl_dr_1>
# {'MovieName': '226. Pirates of the Caribbean: The Curse of the Black Pearl', 'DirectorName': 'Gore Verbinski', 'Top Four Movies': 'Rango,Pirates of the Caribbean: The Curse of the Black Pearl,A Cure for Wellness,The Lone Ranger'}
# 2024-04-06 00:17:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0943758/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0036868/?ref_=chttp_t_224)
# 2024-04-06 00:17:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0943758/?ref_=tt_cl_dr_1>
# {'MovieName': '224. The Best Years of Our Lives', 'DirectorName': 'William Wyler', 'Top Four Movies': 'The Best Years of Our Lives,Ben-Hur,Roman Holiday,The Big Country'}
# 2024-04-06 00:17:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0440913/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0113247/?ref_=chttp_t_223)
# 2024-04-06 00:17:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0440913/?ref_=tt_cl_dr_1>
# {'MovieName': '223. La haine', 'DirectorName': 'Mathieu Kassovitz', 'Top Four Movies': "Le fabuleux destin d'Amélie Poulain,La haine,The Fifth Element,Crimson Rivers"}
# 2024-04-06 00:17:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000500/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0381681/?ref_=chttp_t_222)
# 2024-04-06 00:17:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000500/?ref_=tt_cl_dr_1>
# {'MovieName': '222. Before Sunset', 'DirectorName': 'Richard Linklater', 'Top Four Movies': 'Waking Life,Before Midnight,Boyhood,A Scanner Darkly'}
# 2024-04-06 00:17:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0003433/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0019254/?ref_=chttp_t_221)
# 2024-04-06 00:17:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0003433/?ref_=tt_cl_dr_1>
# {'MovieName': "221. La passion de Jeanne d'Arc", 'DirectorName': 'Carl Theodor Dreyer', 'Top Four Movies': "Gertrud,Vampyr,Ordet,La passion de Jeanne d'Arc"}
# 2024-04-06 00:17:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000116/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0088247/?ref_=chttp_t_220)
# 2024-04-06 00:17:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000116/?ref_=tt_cl_dr_1>
# {'MovieName': '220. The Terminator', 'DirectorName': 'James Cameron', 'Top Four Movies': 'Avatar: The Way of Water,Avatar,Alien 2,Titanic'}
# 2024-04-06 00:18:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001243/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0070047/?ref_=chttp_t_225)
# 2024-04-06 00:18:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001243/?ref_=tt_cl_dr_1>
# {'MovieName': '225. The Exorcist', 'DirectorName': 'William Friedkin', 'Top Four Movies': 'To Live and Die in L.A.,The French Connection,The Exorcist,Cruising'}
# 2024-04-06 00:18:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000231/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0091763/?ref_=chttp_t_219)
# 2024-04-06 00:18:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000231/?ref_=tt_cl_dr_1>
# {'MovieName': '219. Platoon', 'DirectorName': 'Oliver Stone', 'Top Four Movies': 'JFK,Platoon,Natural Born Killers,Born on the Fourth of July'}
# 2024-04-06 00:18:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt1895587/?ref_=chttp_t_217> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt3315342/?ref_=chttp_t_216> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0313623/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0395169/?ref_=chttp_t_218)
# 2024-04-06 00:18:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0313623/?ref_=tt_cl_dr_1>
# {'MovieName': '218. Hotel Rwanda', 'DirectorName': 'Terry George', 'Top Four Movies': "Hotel Rwanda,In the Name of the Father,Some Mother's Son,The Promise"}
# 2024-04-06 00:18:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0050976/?ref_=chttp_t_214> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0075148/?ref_=chttp_t_215> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt3170832/?ref_=chttp_t_212> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0046438/?ref_=chttp_t_213> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0118715/?ref_=chttp_t_211> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt1950186/?ref_=chttp_t_210> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0382932/?ref_=chttp_t_209> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0031679/?ref_=chttp_t_208> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0003506/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt3315342/?ref_=chttp_t_216)
# 2024-04-06 00:18:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0003506/?ref_=tt_cl_dr_1>
# {'MovieName': '216. Logan', 'DirectorName': 'James Mangold', 'Top Four Movies': 'Logan,Ford v. Ferrari,Walk the Line,Indiana Jones and the Dial of Destiny'}
# 2024-04-06 00:18:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0565336/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt1895587/?ref_=chttp_t_217)
# 2024-04-06 00:18:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0565336/?ref_=tt_cl_dr_1>
# {'MovieName': '217. Spotlight', 'DirectorName': 'Tom McCarthy', 'Top Four Movies': 'The Station Agent,Win Win,The Visitor,Spotlight'}
# 2024-04-06 00:18:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0892769/?ref_=chttp_t_206> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:18:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000005/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0050976/?ref_=chttp_t_214)
# 2024-04-06 00:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000005/?ref_=tt_cl_dr_1>
# {'MovieName': '214. Det Sjunde Inseglet', 'DirectorName': 'Ingmar Bergman', 'Top Four Movies': 'Smultronstället,Fanny Och Alexander,Det Sjunde Inseglet,Cries & Whispers'}
# 2024-04-06 00:18:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm1049433/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt3170832/?ref_=chttp_t_212)
# ...
# 2024-04-06 00:20:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0594503/?ref_=tt_cl_dr_1>
# {'MovieName': '32. Spirited Away', 'DirectorName': 'Hayao Miyazaki', 'Top Four Movies': 'Spirited Away,My Neighbour Totoro,Hauru No Ugoku Shiro,Mononoke-hime'}
# 2024-04-06 00:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000591/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0253474/?ref_=chttp_t_33)
# 2024-04-06 00:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0102926/?ref_=chttp_t_24> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000709/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0088763/?ref_=chttp_t_31)
# 2024-04-06 00:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0047478/?ref_=chttp_t_23> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000591/?ref_=tt_cl_dr_1>
# {'MovieName': '33. The Pianist', 'DirectorName': 'Roman Polanski', 'Top Four Movies': "Chinatown,Le locataire,The Ghost Writer,Rosemary's Baby"}
# 2024-04-06 00:20:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000709/?ref_=tt_cl_dr_1>
# {'MovieName': '31. Back to the Future', 'DirectorName': 'Robert Zemeckis', 'Top Four Movies': 'Back to the Future,Forrest Gump,Contact,Flight'}
# 2024-04-06 00:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0038650/?ref_=chttp_t_22> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001104/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0120689/?ref_=chttp_t_28)
# 2024-04-06 00:20:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001104/?ref_=tt_cl_dr_1>
# {'MovieName': '28. The Green Mile', 'DirectorName': 'Frank Darabont', 'Top Four Movies': 'The Shawshank Redemption,The Green Mile,The Mist,The Walking Dead'}
# 2024-04-06 00:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0816692/?ref_=chttp_t_21> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000905/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0118799/?ref_=chttp_t_27)
# 2024-04-06 00:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000184/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0076759/?ref_=chttp_t_30)
# 2024-04-06 00:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0576987/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0317248/?ref_=chttp_t_26)
# 2024-04-06 00:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0114369/?ref_=chttp_t_20> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000116/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0103064/?ref_=chttp_t_29)
# 2024-04-06 00:20:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000905/?ref_=tt_cl_dr_1>
# {'MovieName': '27. Life Is Beautiful', 'DirectorName': 'Roberto Benigni', 'Top Four Movies': 'Life Is Beautiful,La tigre e la neve,Down by Law,Johnny Stecchino'}
# 2024-04-06 00:20:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000184/?ref_=tt_cl_dr_1>
# {'MovieName': '30. Star Wars: Episode IV - A New Hope', 'DirectorName': 'George Lucas', 'Top Four Movies': 'Star Wars: Episode IV - A New Hope,THX 1138,American Graffiti,Raiders of the Lost Ark'}
# 2024-04-06 00:20:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0576987/?ref_=tt_cl_dr_1>
# {'MovieName': '26. City of God', 'DirectorName': 'Fernando Meirelles', 'Top Four Movies': 'The Constant Gardener,Blindness,The Two Popes,City of God'}
# 2024-04-06 00:20:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000116/?ref_=tt_cl_dr_1>
# {'MovieName': '29. Terminator 2: Judgment Day', 'DirectorName': 'James Cameron', 'Top Four Movies': 'Avatar: The Way of Water,Avatar,Alien 2,Titanic'}
# 2024-04-06 00:20:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0073486/?ref_=chttp_t_19> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0099685/?ref_=chttp_t_18> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000591/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0071315/?ref_=chttp_t_161)
# 2024-04-06 00:20:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000591/?ref_=tt_cl_dr_1>
# {'MovieName': '161. Chinatown', 'DirectorName': 'Roman Polanski', 'Top Four Movies': "Chinatown,Le locataire,The Ghost Writer,Rosemary's Baby"}
# 2024-04-06 00:20:16 [scrapy.extensions.logstats] INFO: Crawled 477 pages (at 207 pages/min), scraped 233 items (at 103 items/min)
# 2024-04-06 00:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000229/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0120815/?ref_=chttp_t_25)
# 2024-04-06 00:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0133093/?ref_=chttp_t_17> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001129/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0102926/?ref_=chttp_t_24)
# 2024-04-06 00:20:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000229/?ref_=tt_cl_dr_1>
# {'MovieName': '25. Saving Private Ryan', 'DirectorName': 'Steven Spielberg', 'Top Four Movies': "Schindler's List,E.T. The Extra-Terrestrial,Saving Private Ryan,Raiders of the Lost Ark"}
# 2024-04-06 00:20:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001129/?ref_=tt_cl_dr_1>
# {'MovieName': '24. The Silence of the Lambs', 'DirectorName': 'Jonathan Demme', 'Top Four Movies': 'The Silence of the Lambs,Rachel Getting Married,Philadelphia,Adaptation.'}
# 2024-04-06 00:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000041/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0047478/?ref_=chttp_t_23)
# 2024-04-06 00:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0080684/?ref_=chttp_t_16> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000041/?ref_=tt_cl_dr_1>
# {'MovieName': '23. Shichinin No Samurai', 'DirectorName': 'Akira Kurosawa', 'Top Four Movies': 'The Hidden Fortress,Kagemusha,Ran,Shichinin No Samurai'}
# 2024-04-06 00:20:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001008/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0038650/?ref_=chttp_t_22)
# 2024-04-06 00:20:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001008/?ref_=tt_cl_dr_1>
# {'MovieName': "22. It's a Wonderful Life", 'DirectorName': 'Frank Capra', 'Top Four Movies': "It's a Wonderful Life,It Happened One Night,You Can't Take It with You,Mr. Smith Goes to Washington"}
# 2024-04-06 00:20:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0978762/?ref_=chttp_t_207> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0634240/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0816692/?ref_=chttp_t_21)
# 2024-04-06 00:20:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0634240/?ref_=tt_cl_dr_1>
# {'MovieName': '21. Interstellar', 'DirectorName': 'Christopher Nolan', 'Top Four Movies': 'Tenet,Interstellar,Inception,The Prestige'}
# 2024-04-06 00:20:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0074958/?ref_=chttp_t_229> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000399/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0114369/?ref_=chttp_t_20)
# 2024-04-06 00:20:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt1028532/?ref_=chttp_t_233> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000399/?ref_=tt_cl_dr_1>
# {'MovieName': '20. Se7en', 'DirectorName': 'David Fincher', 'Top Four Movies': 'Se7en,Zodiac,Gone Girl,The Social Network'}
# 2024-04-06 00:20:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0317705/?ref_=chttp_t_232> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001232/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0073486/?ref_=chttp_t_19)
# 2024-04-06 00:20:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001232/?ref_=tt_cl_dr_1>
# {'MovieName': "19. One Flew Over the Cuckoo's Nest", 'DirectorName': 'Milos Forman', 'Top Four Movies': "One Flew Over the Cuckoo's Nest,Amadeus,The People vs. Larry Flynt,Hair"}
# 2024-04-06 00:20:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000217/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0099685/?ref_=chttp_t_18)
# 2024-04-06 00:20:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000217/?ref_=tt_cl_dr_1>
# {'MovieName': '18. GoodFellas', 'DirectorName': 'Martin Scorsese', 'Top Four Movies': 'Killers of the Flower Moon,Taxi Driver,Mean Streets,GoodFellas'}
# 2024-04-06 00:20:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000399/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0137523/?ref_=chttp_t_13)
# 2024-04-06 00:20:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0000694/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0087884/?ref_=chttp_t_250)
# 2024-04-06 00:20:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000399/?ref_=tt_cl_dr_1>
# {'MovieName': '13. Fight Club', 'DirectorName': 'David Fincher', 'Top Four Movies': 'Se7en,Zodiac,Gone Girl,The Social Network'}
# 2024-04-06 00:20:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0000694/?ref_=tt_cl_dr_1>
# {'MovieName': '250. Paris, Texas', 'DirectorName': 'Wim Wenders', 'Top Four Movies': 'Wings of Desire,Perfect Days,Paris, Texas,Bis ans Ende der Welt'}
# 2024-04-06 00:20:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0449984/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0080684/?ref_=chttp_t_16)
# 2024-04-06 00:20:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0449984/?ref_=tt_cl_dr_1>
# {'MovieName': '16. Star Wars: Episode V - The Empire Strikes Back', 'DirectorName': 'Irvin Kershner', 'Top Four Movies': 'Star Wars: Episode V - The Empire Strikes Back,Never Say Never Again,RoboCop 2,On Deadly Ground'}
# 2024-04-06 00:20:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0254178/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0978762/?ref_=chttp_t_207)
# 2024-04-06 00:20:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0254178/?ref_=tt_cl_dr_1>
# {'MovieName': '207. Mary and Max', 'DirectorName': 'Adam Elliot', 'Top Four Movies': 'Mary and Max,Harvie Krumpet,Brother,Cousin'}
# 2024-04-06 00:20:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0905154/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0133093/?ref_=chttp_t_17)
# 2024-04-06 00:20:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0905154/?ref_=tt_cl_dr_1>
# {'MovieName': '17. The Matrix', 'DirectorName': 'Lana Wachowski', 'Top Four Movies': 'The Matrix,Bound,Cloud Atlas,Jupiter Ascending'}
# 2024-04-06 00:20:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0001486/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0074958/?ref_=chttp_t_229)
# 2024-04-06 00:20:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0001486/?ref_=tt_cl_dr_1>
# {'MovieName': '229. Network', 'DirectorName': 'Sidney Lumet', 'Top Four Movies': "12 Angry Men,Before the Devil Knows You're Dead,Serpico,Dog Day Afternoon"}
# 2024-04-06 00:20:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0002120/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt1028532/?ref_=chttp_t_233)
# 2024-04-06 00:20:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0002120/?ref_=tt_cl_dr_1>
# {'MovieName': "233. Hachi: A Dog's Tale", 'DirectorName': 'Lasse Hallström', 'Top Four Movies': "What's Eating Gilbert Grape,Chocolat,Mitt liv som hund,The Cider House Rules"}
# 2024-04-06 00:20:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0083348/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0317705/?ref_=chttp_t_232)
# 2024-04-06 00:20:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0083348/?ref_=tt_cl_dr_1>
# {'MovieName': '232. The Incredibles', 'DirectorName': 'Brad Bird', 'Top Four Movies': 'The Incredibles,Ratatouille,Incredibles 2,The Iron Giant'}
# 2024-04-06 00:20:41 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.imdb.com/title/tt0169547/?ref_=chttp_t_73> (failed 1 times): 504 Gateway Time-out
# 2024-04-06 00:20:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0169547/?ref_=chttp_t_73> (referer: https://www.imdb.com/chart/top/)
# 2024-04-06 00:20:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/name/nm0005222/?ref_=tt_cl_dr_1> (referer: https://www.imdb.com/title/tt0169547/?ref_=chttp_t_73)
# 2024-04-06 00:20:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/name/nm0005222/?ref_=tt_cl_dr_1>
# {'MovieName': '73. American Beauty', 'DirectorName': 'Sam Mendes', 'Top Four Movies': '1917,Road to Perdition,Skyfall,Revolutionary Road'}
# 2024-04-06 00:20:45 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-04-06 00:20:45 [scrapy.extensions.feedexport] INFO: Stored csv feed (250 items) in: MovieRecommendation_using_scrapy.csv
# 2024-04-06 00:20:45 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 370350,
#  'downloader/request_count': 509,
#  'downloader/request_method_count/GET': 509,
#  'downloader/response_bytes': 117002152,
#  'downloader/response_count': 509,
#  'downloader/response_status_count/200': 501,
#  'downloader/response_status_count/504': 8,
#  'elapsed_time_seconds': 209.135197,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 4, 5, 18, 50, 45, 352300),
#  'httpcompression/response_bytes': 618513936,
#  'httpcompression/response_count': 501,
#  'item_scraped_count': 250,
#  'log_count/DEBUG': 774,
#  'log_count/ERROR': 2,
#  'log_count/INFO': 14,
#  'request_depth_max': 2,
#  'response_received_count': 501,
#  'retry/count': 8,
#  'retry/reason_count/504 Gateway Time-out': 8,
#  'scheduler/dequeued': 509,
#  'scheduler/dequeued/memory': 509,
#  'scheduler/enqueued': 509,
#  'scheduler/enqueued/memory': 509,
#  'start_time': datetime.datetime(2024, 4, 5, 18, 47, 16, 217103)}
# 2024-04-06 00:20:45 [scrapy.core.engine] INFO: Spider closed (finished)
